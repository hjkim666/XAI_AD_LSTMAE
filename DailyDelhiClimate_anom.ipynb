# %% [markdown]
# # 1. Importing some Libraries

# %%
# pip install -U kaleido
# conda install -c conda-forge python-kaleido

# %%
#pip install joblib

# %%
import numpy as np
import pandas as pd

from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import plotly.graph_objects as go
import plotly.io as pio
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt

import holoviews as hv
import joblib
from holoviews import opts
hv.extension('bokeh')


from tensorflow.keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from sklearn import metrics
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# Function to convert ISO 8601 time to datetime
def ISO_8601_To_Datetime(s):
    return datetime.strptime(s, '%Y-%m-%dT%H:%M:%SZ')

# %% [markdown]
# # 1. Readn the Data

# %%
# Read The data
df = pd.read_csv('Data\DailyDelhiClimateTrain.csv', index_col=0)

df.head()
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000

# %%
df.iloc[0]
# Out:
# meantemp          10.000000
# humidity          84.500000
# wind_speed         0.000000
# meanpressure    1015.666667
# Name: 2013-01-01, dtype: float64

# %%
train = df['2013-01-01': '2016-06-30']
test = df['2016-06-30':]
print("Training dataset shape:", train.shape)
print("Test dataset shape:", test.shape)
# Out:
# Training dataset shape: (1277, 4)
# Test dataset shape: (186, 4)

# %% [markdown]
# ## 2. Visualize the timeseries

# %%
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(train['meantemp'], label='Meantemp', color='blue', animated = True, linewidth=1)
ax.plot(train['humidity'], label='humidity', color='red', animated = True, linewidth=1)
plt.legend(loc='upper right')
ax.set_title('Meantemp Vs Humidity : 2013 - 2017', fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(train['wind_speed'], label='wind_speed', color='blue', animated = True, linewidth=1)
ax.plot(train['meanpressure'], label='meanpressure', color='red', animated = True, linewidth=1)
plt.legend(loc='upper left')
ax.set_title('wind_speed Vs meanpressure : 2013 - 2017', fontsize=16)
plt.show()

# %% [markdown]
# ## 3. Preprocessing

# %% [markdown]
# ### 3.1 Standardize the data

# %%
# normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(train)
X_test = scaler.transform(test)
scaler_filename = "scaler_data"
joblib.dump(scaler, scaler_filename)
# Out:
# ['scaler_data']

# %%
# reshape inputs for LSTM [samples, timesteps, features]
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
print("Training data shape:", X_train.shape)
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
print("Test data shape:", X_test.shape)
# Out:
# Training data shape: (1277, 1, 4)
# Test data shape: (186, 1, 4)

# %% [markdown]
# ## 4. LSTM Model

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_51 (InputLayer)       [(None, 1, 4)]            0
#
#  lstm_313 (LSTM)             (None, 1, 16)             1344
#
#  lstm_314 (LSTM)             (None, 4)                 336
#
#  repeat_vector_78 (RepeatVe  (None, 1, 4)              0
#  ctor)
#
#  lstm_315 (LSTM)             (None, 1, 4)              144
#
#  lstm_316 (LSTM)             (None, 1, 16)             1344
#
#  time_distributed_78 (TimeD  (None, 1, 4)              68
#  istributed)
#
# =================================================================
# Total params: 3236 (12.64 KB)
# Trainable params: 3236 (12.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fit the model to the data
nb_epochs = 25
batch_size = 10
history = model.fit(X_train, X_train, epochs=nb_epochs, batch_size=batch_size, validation_split=0.05).history
# Out:
# Epoch 1/25
# 122/122 [==============================] - 9s 10ms/step - loss: 0.2727 - accuracy: 0.4427 - val_loss: 0.2438 - val_accuracy: 0.9844
# Epoch 2/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.1317 - accuracy: 0.5029 - val_loss: 0.1422 - val_accuracy: 0.9844
# Epoch 3/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.5120 - val_loss: 0.1361 - val_accuracy: 0.9844
# Epoch 4/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.0980 - accuracy: 0.6125 - val_loss: 0.1255 - val_accuracy: 0.9844
# Epoch 5/25
# 122/122 [==============================] - 0s 3ms/step - loss: 0.0937 - accuracy: 0.6381 - val_loss: 0.1147 - val_accuracy: 0.9844
# Epoch 6/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0877 - accuracy: 0.8302 - val_loss: 0.1119 - val_accuracy: 0.9844
# Epoch 7/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0826 - accuracy: 0.8640 - val_loss: 0.1108 - val_accuracy: 0.9844
# Epoch 8/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0781 - accuracy: 0.8590 - val_loss: 0.0898 - val_accuracy: 0.9844
# Epoch 9/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0726 - accuracy: 0.8648 - val_loss: 0.0875 - val_accuracy: 0.9844
# Epoch 10/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 0.8664 - val_loss: 0.0723 - val_accuracy: 0.9844
# Epoch 11/25
# 122/122 [==============================] - 1s 4ms/step - loss: 0.0623 - accuracy: 0.8706 - val_loss: 0.0600 - val_accuracy: 0.9844
# Epoch 12/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0604 - accuracy: 0.8747 - val_loss: 0.0738 - val_accuracy: 0.9844
# Epoch 13/25
# 122/122 [==============================] - 1s 4ms/step - loss: 0.0593 - accuracy: 0.8780 - val_loss: 0.0592 - val_accuracy: 0.9844
# Epoch 14/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0582 - accuracy: 0.8805 - val_loss: 0.0584 - val_accuracy: 0.9844
# Epoch 15/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0576 - accuracy: 0.8887 - val_loss: 0.0486 - val_accuracy: 1.0000
# Epoch 16/25
# 122/122 [==============================] - 1s 4ms/step - loss: 0.0564 - accuracy: 0.8879 - val_loss: 0.0563 - val_accuracy: 1.0000
# Epoch 17/25
# 122/122 [==============================] - 1s 5ms/step - loss: 0.0548 - accuracy: 0.8912 - val_loss: 0.0492 - val_accuracy: 1.0000
# Epoch 18/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0518 - accuracy: 0.9027 - val_loss: 0.0486 - val_accuracy: 1.0000
# Epoch 19/25
# 122/122 [==============================] - 1s 5ms/step - loss: 0.0465 - accuracy: 0.9167 - val_loss: 0.0377 - val_accuracy: 1.0000
# Epoch 20/25
# 122/122 [==============================] - 1s 6ms/step - loss: 0.0402 - accuracy: 0.9373 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 21/25
# 122/122 [==============================] - 1s 5ms/step - loss: 0.0351 - accuracy: 0.9505 - val_loss: 0.0341 - val_accuracy: 1.0000
# Epoch 22/25
# 122/122 [==============================] - 1s 6ms/step - loss: 0.0332 - accuracy: 0.9530 - val_loss: 0.0370 - val_accuracy: 1.0000
# Epoch 23/25
# 122/122 [==============================] - 1s 6ms/step - loss: 0.0322 - accuracy: 0.9580 - val_loss: 0.0373 - val_accuracy: 1.0000
# Epoch 24/25
# 122/122 [==============================] - 1s 5ms/step - loss: 0.0311 - accuracy: 0.9596 - val_loss: 0.0386 - val_accuracy: 1.0000
# Epoch 25/25
# 122/122 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9613 - val_loss: 0.0307 - val_accuracy: 1.0000

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
# Check how loss & mse went down
epoch_loss = history['loss']
epoch_val_loss = history['val_loss']
epoch_mae = history['accuracy']
epoch_val_mae = history['val_accuracy']

plt.figure(figsize=(8,5))
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Test Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")

#lt.title('Loss')
plt.legend(loc='best')
plt.savefig('DeilyDelhiClimate_Figure_Loss_LSTM_AE.jpeg')
plt.show()

# %%
# Check how loss & mse went down
epoch_loss = history['loss']
epoch_val_loss = history['val_loss']
epoch_mae = history['accuracy']
epoch_val_mae = history['val_accuracy']

plt.figure(figsize=(8,5))

plt.plot(range(0,len(epoch_mae)), epoch_mae, 'b-', linewidth=2, label='Train Acc')
plt.plot(range(0,len(epoch_val_mae)), epoch_val_mae, 'r-', linewidth=2,label='Test Acc')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
#plt.title('Accuracy')
plt.legend(loc='lower right')

plt.savefig('DeilyDelhiClimate_Figure_Acc_LSTM_AE.jpeg')
plt.show()

# %% [markdown]
# ## Distribution of Loss Function

# %%
# # By plotting the distribution of the calculated loss in the training set, one can use this to identify a suitable threshold value for identifying an anomaly

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=train.columns)
X_pred.index = train.index

scored = pd.DataFrame(index=train.index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue');
plt.xlim([0.0,.5])
# Out:
# 40/40 [==============================] - 1s 2ms/step
# C:\Users\MWAMBA\AppData\Local\Temp\ipykernel_23820\3269023118.py:12: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# (0.0, 0.5)

# %%
# calculate the loss on the test set
X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=test.columns)
X_pred.index = test.index

scored = pd.DataFrame(index=test.index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])

# Calculate Mean Squared Error (MSE)
mse = np.mean(np.power(test - X_pred, 2), axis=1)

# Compute mean and standard deviation of MSE
mse_mean = np.mean(mse)
mse_std = np.std(mse)

# Set threshold for anomaly detection (for example, using a multiplier of standard deviation)
threshold = mse_mean + 2 * mse_std  # Adjust multiplier according to your data and anomaly sensitivity
print("Threshold:", threshold)

scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = threshold
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head()
# Out:
# 6/6 [==============================] - 0s 2ms/step
#             Loss_mae  Threshold  Anomaly
# date
# 2016-06-30  0.028457       0.07    False
# 2016-07-01  0.022607       0.07    False
# 2016-07-02  0.015954       0.07    False
# 2016-07-03  0.034788       0.07    False
# 2016-07-04  0.028450       0.07    False

# %%
# calculate the same metrics for the training set 
# and merge all data in a single dataframe for plotting
X_pred_train = model.predict(X_train)
X_pred_train = X_pred_train.reshape(X_pred_train.shape[0], X_pred_train.shape[2])
X_pred_train = pd.DataFrame(X_pred_train, columns=train.columns)
X_pred_train.index = train.index

scored_train = pd.DataFrame(index=train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-Xtrain), axis = 1)
scored_train['Threshold'] = threshold
scored_train['Anomaly'] = np.where(scored_train['Loss_mae'] > scored_train['Threshold'], 1, 0)
#scored = pd.concat([scored_train, scored])
# Out:
# 40/40 [==============================] - 0s 2ms/step

# %%
# plot bearing failure time plot
scored_train.plot(logy=True,  figsize=(16,9), ylim=[1e-2,1e2], color=['blue','red'])
# Out:
# <Axes: xlabel='date'>

# %%
scored_train['Anomaly'].value_counts()
# Out:
# Anomaly
# 0    1232
# 1      45
# Name: count, dtype: int64

# %%
scored_train
# Out:
#             Loss_mae  Threshold  Anomaly
# date
# 2013-01-01  0.057862       0.07        0
# 2013-01-02  0.067206       0.07        0
# 2013-01-03  0.068974       0.07        0
# 2013-01-04  0.045639       0.07        0
# 2013-01-05  0.071647       0.07        1
# ...              ...        ...      ...
# 2016-06-26  0.021630       0.07        0
# 2016-06-27  0.013769       0.07        0
# 2016-06-28  0.016707       0.07        0
# 2016-06-29  0.019908       0.07        0
# 2016-06-30  0.028457       0.07        0
#
# [1277 rows x 3 columns]

# %%
train
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000
# ...               ...        ...         ...           ...
# 2016-06-26  34.866667  57.466667    7.660000   1000.375000
# 2016-06-27  34.312500  61.250000    7.993750    998.866667
# 2016-06-28  30.785714  75.071429    5.435714   1001.500000
# 2016-06-29  35.375000  58.875000    8.450000   1001.187500
# 2016-06-30  35.466667  60.200000    6.793333    997.866667
#
# [1277 rows x 4 columns]

# %%
# Extract a column from the first DataFrame
extracted_col = scored_train[['Loss_mae','Threshold','Anomaly']]

# %%
df_anomaly = pd.concat([train, extracted_col], axis=1)

df_anomaly
# Out:
#              meantemp   humidity  wind_speed  meanpressure  Loss_mae  Threshold  Anomaly
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667  0.057862       0.07        0
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000  0.067206       0.07        0
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667  0.068974       0.07        0
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667  0.045639       0.07        0
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000  0.071647       0.07        1
# ...               ...        ...         ...           ...       ...        ...      ...
# 2016-06-26  34.866667  57.466667    7.660000   1000.375000  0.021630       0.07        0
# 2016-06-27  34.312500  61.250000    7.993750    998.866667  0.013769       0.07        0
# 2016-06-28  30.785714  75.071429    5.435714   1001.500000  0.016707       0.07        0
# 2016-06-29  35.375000  58.875000    8.450000   1001.187500  0.019908       0.07        0
# 2016-06-30  35.466667  60.200000    6.793333    997.866667  0.028457       0.07        0
#
# [1277 rows x 7 columns]

# %%
df_anomaly['Anomaly'].value_counts()
# Out:
# Anomaly
# 0    1232
# 1      45
# Name: count, dtype: int64
