# %% [markdown]
# # 1. Importing some Libraries

# %%
# pip install -U kaleido
# conda install -c conda-forge python-kaleido

# %%
#pip install joblib

# %%
import numpy as np
import pandas as pd

from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import plotly.graph_objects as go
import plotly.io as pio
from sklearn.ensemble import IsolationForest
import matplotlib.pyplot as plt

import holoviews as hv
import joblib
from holoviews import opts
hv.extension('bokeh')


from tensorflow.keras.layers import Input, Dropout, Dense, LSTM, TimeDistributed, RepeatVector
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from sklearn import metrics
import tensorflow as tf
import keras.backend as K
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# Function to convert ISO 8601 time to datetime
def ISO_8601_To_Datetime(s):
    return datetime.strptime(s, '%Y-%m-%dT%H:%M:%SZ')

# %% [markdown]
# # 1. Readn the Data

# %%
# Read The data
df = pd.read_csv('Data\yahoo_Stock.csv', index_col=0)

df.head()
# Out:
#                    High          Low         Open        Close        Volume    Adj Close
# Date
# 2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088  3.587980e+09  2086.590088
# 2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893  3.884930e+09  2089.139893
# 2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09  2088.870117
# 2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09  2088.870117
# 2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107  1.466840e+09  2090.110107

# %%
df
# Out:
#                    High          Low         Open        Close        Volume    Adj Close
# Date
# 2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088  3.587980e+09  2086.590088
# 2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893  3.884930e+09  2089.139893
# 2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09  2088.870117
# 2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09  2088.870117
# 2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107  1.466840e+09  2090.110107
# ...                 ...          ...          ...          ...           ...          ...
# 2020-11-16  3628.510010  3600.159912  3600.159912  3626.909912  5.281980e+09  3626.909912
# 2020-11-17  3623.110107  3588.679932  3610.310059  3609.530029  4.799570e+09  3609.530029
# 2020-11-18  3619.090088  3567.330078  3612.090088  3567.790039  5.274450e+09  3567.790039
# 2020-11-19  3585.219971  3543.840088  3559.409912  3581.870117  4.347200e+09  3581.870117
# 2020-11-20  3581.229980  3556.850098  3579.310059  3557.540039  2.236662e+09  3557.540039
#
# [1825 rows x 6 columns]

# %%
train = df['2015-11-23': '2020-06-30']
test = df['2020-01-30':]
print("Training dataset shape:", train.shape)
print("Test dataset shape:", test.shape)
# Out:
# Training dataset shape: (1682, 6)
# Test dataset shape: (296, 6)

# %% [markdown]
# ## 2. Visualize the timeseries

# %%
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(train['High'], label='High', color='blue', animated = True, linewidth=2)
ax.plot(train['Low'], label='Low', color='red', animated = True, linewidth=2)
plt.legend(loc='upper right')
ax.set_title('High Vs Low : 2015-11-23 - 2020-11-20', fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(train['Open'], label='Open', color='blue', animated = True, linewidth=2)
ax.plot(train['Close'], label='Close', color='red', animated = True, linewidth=2)
plt.legend(loc='upper right')
ax.set_title('Open Vs Close : 2015-11-23 - 2020-11-20', fontsize=16)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(train['Volume'], label='Volume', color='red', animated = True, linewidth=1)
ax.plot(train['Adj Close'], label='Adj Close', color='red', animated = True, linewidth=1)
plt.legend(loc='upper right')
ax.set_title('Open Vs Close : 2015-11-23 - 2020-11-20', fontsize=16)
plt.show()

# %% [markdown]
# ## 3. Preprocessing

# %% [markdown]
# ### 3.1 Standardize the data

# %%
# normalize the data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(train)
X_test = scaler.transform(test)
scaler_filename = "scaler_data"
joblib.dump(scaler, scaler_filename)
# Out:
# ['scaler_data']

# %%
# reshape inputs for LSTM [samples, timesteps, features]
X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
print("Training data shape:", X_train.shape)
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
print("Test data shape:", X_test.shape)
# Out:
# Training data shape: (1682, 1, 6)
# Test data shape: (296, 1, 6)

# %% [markdown]
# ## 4. LSTM Model

# %%
# define the autoencoder network model
def autoencoder_model(X):
    inputs = Input(shape=(X.shape[1], X.shape[2]))
    L1 = LSTM(16, activation='relu', return_sequences=True, 
              kernel_regularizer=regularizers.l2(0.00))(inputs)
    L2 = LSTM(4, activation='relu', return_sequences=False)(L1)
    L3 = RepeatVector(X.shape[1])(L2)
    L4 = LSTM(4, activation='relu', return_sequences=True)(L3)
    L5 = LSTM(16, activation='relu', return_sequences=True)(L4)
    output = TimeDistributed(Dense(X.shape[2]))(L5)    
    model = Model(inputs=inputs, outputs=output)
    return model

# %%
# create the autoencoder model
model = autoencoder_model(X_train)
model.compile(optimizer='adam', loss='mae', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 1, 6)]            0
#
#  lstm_8 (LSTM)               (None, 1, 16)             1472
#
#  lstm_9 (LSTM)               (None, 4)                 336
#
#  repeat_vector_2 (RepeatVec  (None, 1, 4)              0
#  tor)
#
#  lstm_10 (LSTM)              (None, 1, 4)              144
#
#  lstm_11 (LSTM)              (None, 1, 16)             1344
#
#  time_distributed_2 (TimeDi  (None, 1, 6)              102
#  stributed)
#
# =================================================================
# Total params: 3398 (13.27 KB)
# Trainable params: 3398 (13.27 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fit the model to the data
nb_epochs = 75
batch_size = 10
history = model.fit(X_train, X_train, epochs=nb_epochs, batch_size=batch_size, validation_split=0.05).history
# Out:
# Epoch 1/75
# 160/160 [==============================] - 7s 7ms/step - loss: 0.3377 - accuracy: 0.1853 - val_loss: 0.3764 - val_accuracy: 0.3882
# Epoch 2/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.1025 - accuracy: 0.1997 - val_loss: 0.1087 - val_accuracy: 0.3765
# Epoch 3/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0605 - accuracy: 0.1578 - val_loss: 0.1097 - val_accuracy: 0.2118
# Epoch 4/75
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 0.2473 - val_loss: 0.0809 - val_accuracy: 0.2000
# Epoch 5/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0295 - accuracy: 0.4590 - val_loss: 0.0866 - val_accuracy: 0.1059
# Epoch 6/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0250 - accuracy: 0.5128 - val_loss: 0.0936 - val_accuracy: 0.1647
# Epoch 7/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0233 - accuracy: 0.4703 - val_loss: 0.0863 - val_accuracy: 0.1882
# Epoch 8/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0222 - accuracy: 0.5166 - val_loss: 0.0825 - val_accuracy: 0.3882
# Epoch 9/75
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.5028 - val_loss: 0.0771 - val_accuracy: 0.1647
# Epoch 10/75
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 0.5053 - val_loss: 0.0651 - val_accuracy: 0.2118
# Epoch 11/75
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0200 - accuracy: 0.5285 - val_loss: 0.0639 - val_accuracy: 0.2118
# Epoch 12/75
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.4934 - val_loss: 0.0650 - val_accuracy: 0.1765
# Epoch 13/75
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 0.5254 - val_loss: 0.0643 - val_accuracy: 0.0824
# Epoch 14/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0187 - accuracy: 0.5191 - val_loss: 0.0604 - val_accuracy: 0.2706
# Epoch 15/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0185 - accuracy: 0.4984 - val_loss: 0.0620 - val_accuracy: 0.2118
# Epoch 16/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0183 - accuracy: 0.5222 - val_loss: 0.0616 - val_accuracy: 0.0118
# Epoch 17/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0178 - accuracy: 0.5041 - val_loss: 0.0616 - val_accuracy: 0.1176
# Epoch 18/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0176 - accuracy: 0.5028 - val_loss: 0.0609 - val_accuracy: 0.2118
# Epoch 19/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0177 - accuracy: 0.5072 - val_loss: 0.0646 - val_accuracy: 0.2235
# Epoch 20/75
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0173 - accuracy: 0.4796 - val_loss: 0.0589 - val_accuracy: 0.2118
# Epoch 21/75
# 160/160 [==============================] - 0s 3ms/step - loss: 0.0175 - accuracy: 0.5009 - val_loss: 0.0606 - val_accuracy: 0.1529
# Epoch 22/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0170 - accuracy: 0.5191 - val_loss: 0.0595 - val_accuracy: 0.0706
# Epoch 23/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0171 - accuracy: 0.5291 - val_loss: 0.0591 - val_accuracy: 0.3882
# Epoch 24/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0171 - accuracy: 0.5053 - val_loss: 0.0603 - val_accuracy: 0.1647
# Epoch 25/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0170 - accuracy: 0.5153 - val_loss: 0.0615 - val_accuracy: 0.1647
# Epoch 26/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0169 - accuracy: 0.5153 - val_loss: 0.0612 - val_accuracy: 0.0235
# Epoch 27/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0173 - accuracy: 0.4915 - val_loss: 0.0587 - val_accuracy: 0.3765
# Epoch 28/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0169 - accuracy: 0.4984 - val_loss: 0.0572 - val_accuracy: 0.2118
# Epoch 29/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0169 - accuracy: 0.5147 - val_loss: 0.0621 - val_accuracy: 0.4118
# Epoch 30/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0169 - accuracy: 0.5147 - val_loss: 0.0588 - val_accuracy: 0.2118
# Epoch 31/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.5059 - val_loss: 0.0598 - val_accuracy: 0.2118
# Epoch 32/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.5135 - val_loss: 0.0592 - val_accuracy: 0.2118
# Epoch 33/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.5028 - val_loss: 0.0603 - val_accuracy: 0.0471
# Epoch 34/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0169 - accuracy: 0.5097 - val_loss: 0.0570 - val_accuracy: 0.2706
# Epoch 35/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0166 - accuracy: 0.5260 - val_loss: 0.0592 - val_accuracy: 0.2235
# Epoch 36/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.5191 - val_loss: 0.0591 - val_accuracy: 0.3882
# Epoch 37/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0167 - accuracy: 0.4966 - val_loss: 0.0614 - val_accuracy: 0.3882
# Epoch 38/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0165 - accuracy: 0.5022 - val_loss: 0.0586 - val_accuracy: 0.3882
# Epoch 39/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 0.4897 - val_loss: 0.0607 - val_accuracy: 0.2118
# Epoch 40/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0166 - accuracy: 0.5197 - val_loss: 0.0603 - val_accuracy: 0.2353
# Epoch 41/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.4966 - val_loss: 0.0612 - val_accuracy: 0.1882
# Epoch 42/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 0.4997 - val_loss: 0.0603 - val_accuracy: 0.2118
# Epoch 43/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 0.5110 - val_loss: 0.0599 - val_accuracy: 0.2118
# Epoch 44/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 0.4947 - val_loss: 0.0585 - val_accuracy: 0.3882
# Epoch 45/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.5166 - val_loss: 0.0600 - val_accuracy: 0.1176
# Epoch 46/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.5072 - val_loss: 0.0599 - val_accuracy: 0.2235
# Epoch 47/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 0.5028 - val_loss: 0.0612 - val_accuracy: 0.3882
# Epoch 48/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.5197 - val_loss: 0.0613 - val_accuracy: 0.2118
# Epoch 49/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0166 - accuracy: 0.5222 - val_loss: 0.0611 - val_accuracy: 0.3882
# Epoch 50/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0165 - accuracy: 0.5178 - val_loss: 0.0591 - val_accuracy: 0.2000
# Epoch 51/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0166 - accuracy: 0.5047 - val_loss: 0.0612 - val_accuracy: 0.0000e+00
# Epoch 52/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0165 - accuracy: 0.5116 - val_loss: 0.0624 - val_accuracy: 0.2235
# Epoch 53/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0165 - accuracy: 0.4966 - val_loss: 0.0593 - val_accuracy: 0.0824
# Epoch 54/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0164 - accuracy: 0.5272 - val_loss: 0.0572 - val_accuracy: 0.2235
# Epoch 55/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0166 - accuracy: 0.4978 - val_loss: 0.0605 - val_accuracy: 0.3059
# Epoch 56/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0165 - accuracy: 0.5122 - val_loss: 0.0629 - val_accuracy: 0.3882
# Epoch 57/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 0.5235 - val_loss: 0.0594 - val_accuracy: 0.1765
# Epoch 58/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0166 - accuracy: 0.4972 - val_loss: 0.0619 - val_accuracy: 0.0588
# Epoch 59/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0164 - accuracy: 0.5247 - val_loss: 0.0611 - val_accuracy: 0.2353
# Epoch 60/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0165 - accuracy: 0.5103 - val_loss: 0.0586 - val_accuracy: 0.2706
# Epoch 61/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 0.5110 - val_loss: 0.0614 - val_accuracy: 0.3882
# Epoch 62/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0164 - accuracy: 0.5122 - val_loss: 0.0630 - val_accuracy: 0.2118
# Epoch 63/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0165 - accuracy: 0.4984 - val_loss: 0.0600 - val_accuracy: 0.1882
# Epoch 64/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.5085 - val_loss: 0.0598 - val_accuracy: 0.0118
# Epoch 65/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0166 - accuracy: 0.5160 - val_loss: 0.0591 - val_accuracy: 0.0000e+00
# Epoch 66/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.5128 - val_loss: 0.0614 - val_accuracy: 0.2588
# Epoch 67/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0165 - accuracy: 0.4991 - val_loss: 0.0624 - val_accuracy: 0.1059
# Epoch 68/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0165 - accuracy: 0.5047 - val_loss: 0.0616 - val_accuracy: 0.2118
# Epoch 69/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0164 - accuracy: 0.5041 - val_loss: 0.0614 - val_accuracy: 0.2235
# Epoch 70/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0166 - accuracy: 0.5072 - val_loss: 0.0593 - val_accuracy: 0.2118
# Epoch 71/75
# 160/160 [==============================] - 1s 4ms/step - loss: 0.0165 - accuracy: 0.5147 - val_loss: 0.0600 - val_accuracy: 0.2118
# Epoch 72/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0165 - accuracy: 0.5166 - val_loss: 0.0624 - val_accuracy: 0.2235
# Epoch 73/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0165 - accuracy: 0.4840 - val_loss: 0.0615 - val_accuracy: 0.3882
# Epoch 74/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0164 - accuracy: 0.4909 - val_loss: 0.0576 - val_accuracy: 0.2471
# Epoch 75/75
# 160/160 [==============================] - 1s 3ms/step - loss: 0.0164 - accuracy: 0.4915 - val_loss: 0.0595 - val_accuracy: 0.0000e+00

# %%
# plot the training losses
fig, ax = plt.subplots(figsize=(14, 6), dpi=80)
ax.plot(history['loss'], 'b', label='Train', linewidth=2)
ax.plot(history['val_loss'], 'r', label='Validation', linewidth=2)
ax.set_title('Model loss', fontsize=16)
ax.set_ylabel('Loss (mae)')
ax.set_xlabel('Epoch')
ax.legend(loc='upper right')
plt.show()

# %%
# Check how loss & mse went down
epoch_loss = history['loss']
epoch_val_loss = history['val_loss']
epoch_mae = history['accuracy']
epoch_val_mae = history['val_accuracy']

plt.figure(figsize=(8,5))
plt.plot(range(0,len(epoch_loss)), epoch_loss, 'b-', linewidth=2, label='Train Loss')
plt.plot(range(0,len(epoch_val_loss)), epoch_val_loss, 'r-', linewidth=2, label='Test Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")

#lt.title('Loss')
plt.legend(loc='best')
plt.savefig('Yahoo_Stock_Price_Figure_Loss_LSTM_AE.jpeg')
plt.show()

# %% [markdown]
# ## Distribution of Loss Function

# %%
# # By plotting the distribution of the calculated loss in the training set, one can use this to identify a suitable threshold value for identifying an anomaly

# %%
# plot the loss distribution of the training set
X_pred = model.predict(X_train)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=train.columns)
X_pred.index = train.index

scored = pd.DataFrame(index=train.index)
Xtrain = X_train.reshape(X_train.shape[0], X_train.shape[2])
scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtrain), axis = 1)
plt.figure(figsize=(16,9), dpi=80)
plt.title('Loss Distribution', fontsize=16)
sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue');
plt.xlim([0.0,.5])
# Out:
# 53/53 [==============================] - 1s 1ms/step
# C:\Users\MWAMBA\AppData\Local\Temp\ipykernel_16988\3269023118.py:12: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(scored['Loss_mae'], bins = 20, kde= True, color = 'blue');
# (0.0, 0.5)

# %%
""" # calculate the loss on the test set
X_pred = model.predict(X_test)
X_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])
X_pred = pd.DataFrame(X_pred, columns=test.columns)
X_pred.index = test.index

scored = pd.DataFrame(index=test.index)
Xtest = X_test.reshape(X_test.shape[0], X_test.shape[2])


# Calculate Mean Squared Error (MSE)
mse = np.mean(np.power(test - X_pred, 2), axis=1)

# Compute mean and standard deviation of MSE
mse_mean = np.mean(mse)
mse_std = np.std(mse)
print("MSE STD", mse_std)
# Set threshold for anomaly detection (for example, using a multiplier of standard deviation)
threshold = mse_mean + (-0.15) * mse_std  # Adjust multiplier according to your data and anomaly sensitivity
print("Threshold:", threshold)

scored['Loss_mae'] = np.mean(np.abs(X_pred-Xtest), axis = 1)
scored['Threshold'] = threshold
scored['Anomaly'] = scored['Loss_mae'] > scored['Threshold']
scored.head() """
# Out:
# ' # calculate the loss on the test set\nX_pred = model.predict(X_test)\nX_pred = X_pred.reshape(X_pred.shape[0], X_pred.shape[2])\nX_pred = pd.DataFrame(X_pred, columns=test.columns)\nX_pred.index = test.index\n\nscored = pd.DataFrame(index=test.index)\nXtest = X_test.reshape(X_test.shape[0], X_test.shape[2])\n\n\n# Calculate Mean Squared Error (MSE)\nmse = np.mean(np.power(test - X_pred, 2), axis=1)\n\n# Compute mean and standard deviation of MSE\nmse_mean = np.mean(mse)\nmse_std = np.std(mse)\nprint("MSE STD", mse_std)\n# Set threshold for anomaly detection (for example, using a multiplier of standard deviation)\nthreshold = mse_mean + (-0.15) * mse_std  # Adjust multiplier according to your data and anomaly sensitivity\nprint("Threshold:", threshold)\n\nscored[\'Loss_mae\'] = np.mean(np.abs(X_pred-Xtest), axis = 1)\nscored[\'Threshold\'] = threshold\nscored[\'Anomaly\'] = scored[\'Loss_mae\'] > scored[\'Threshold\']\nscored.head() '

# %%
# calculate the same metrics for the training set 
# and merge all data in a single dataframe for plotting
X_pred_train = model.predict(X_train)
X_pred_train = X_pred_train.reshape(X_pred_train.shape[0], X_pred_train.shape[2])
X_pred_train = pd.DataFrame(X_pred_train, columns=train.columns)
X_pred_train.index = train.index

scored_train = pd.DataFrame(index=train.index)
scored_train['Loss_mae'] = np.mean(np.abs(X_pred_train-Xtrain), axis = 1)
scored_train['Threshold'] = 0.05
scored_train['Anomaly'] = np.where(scored_train['Loss_mae'] > scored_train['Threshold'], 1, 0)
#scored = pd.concat([scored_train, scored])
# Out:
# 53/53 [==============================] - 0s 2ms/step

# %%
# plot bearing failure time plot
scored_train.plot(logy=True,  figsize=(16,9), ylim=[1e-2,1e2], color=['blue','red'])
# Out:
# <Axes: xlabel='Date'>

# %%
scored_train['Anomaly'].value_counts()
# Out:
# Anomaly
# 0    1546
# 1     136
# Name: count, dtype: int64

# %%
scored_train
# Out:
#             Loss_mae  Threshold  Anomaly
# Date
# 2015-11-23  0.006386       0.05        0
# 2015-11-24  0.002580       0.05        0
# 2015-11-25  0.022772       0.05        0
# 2015-11-26  0.022772       0.05        0
# 2015-11-27  0.052629       0.05        1
# ...              ...        ...      ...
# 2020-06-26  0.113675       0.05        1
# 2020-06-27  0.113675       0.05        1
# 2020-06-28  0.113675       0.05        1
# 2020-06-29  0.028647       0.05        0
# 2020-06-30  0.035930       0.05        0
#
# [1682 rows x 3 columns]

# %%
train
# Out:
#                    High          Low         Open        Close        Volume    Adj Close
# Date
# 2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088  3.587980e+09  2086.590088
# 2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893  3.884930e+09  2089.139893
# 2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09  2088.870117
# 2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09  2088.870117
# 2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107  1.466840e+09  2090.110107
# ...                 ...          ...          ...          ...           ...          ...
# 2020-06-26  3073.729980  3004.629883  3073.199951  3009.050049  8.098120e+09  3009.050049
# 2020-06-27  3073.729980  3004.629883  3073.199951  3009.050049  8.098120e+09  3009.050049
# 2020-06-28  3073.729980  3004.629883  3073.199951  3009.050049  8.098120e+09  3009.050049
# 2020-06-29  3053.889893  2999.739990  3018.590088  3053.239990  4.462770e+09  3053.239990
# 2020-06-30  3111.510010  3047.830078  3050.199951  3100.290039  4.696280e+09  3100.290039
#
# [1682 rows x 6 columns]

# %%
# Extract a column from the first DataFrame
extracted_col = scored_train[['Loss_mae','Threshold','Anomaly']]

# %%
df_anomaly = pd.concat([train, extracted_col], axis=1)

df_anomaly
# Out:
#                    High          Low         Open        Close        Volume    Adj Close  Loss_mae  Threshold  Anomaly
# Date
# 2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088  3.587980e+09  2086.590088  0.006386       0.05        0
# 2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893  3.884930e+09  2089.139893  0.002580       0.05        0
# 2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09  2088.870117  0.022772       0.05        0
# 2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117  2.852940e+09  2088.870117  0.022772       0.05        0
# 2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107  1.466840e+09  2090.110107  0.052629       0.05        1
# ...                 ...          ...          ...          ...           ...          ...       ...        ...      ...
# 2020-06-26  3073.729980  3004.629883  3073.199951  3009.050049  8.098120e+09  3009.050049  0.113675       0.05        1
# 2020-06-27  3073.729980  3004.629883  3073.199951  3009.050049  8.098120e+09  3009.050049  0.113675       0.05        1
# 2020-06-28  3073.729980  3004.629883  3073.199951  3009.050049  8.098120e+09  3009.050049  0.113675       0.05        1
# 2020-06-29  3053.889893  2999.739990  3018.590088  3053.239990  4.462770e+09  3053.239990  0.028647       0.05        0
# 2020-06-30  3111.510010  3047.830078  3050.199951  3100.290039  4.696280e+09  3100.290039  0.035930       0.05        0
#
# [1682 rows x 9 columns]

# %%
df_anomaly['Anomaly'].value_counts()
# Out:
# Anomaly
# 0    1546
# 1     136
# Name: count, dtype: int64
